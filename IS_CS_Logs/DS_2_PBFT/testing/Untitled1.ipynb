# %%
servers = [
        'localhost:50051',
        'localhost:50052',
        'localhost:50053',
        'localhost:50054',
        'localhost:50055',
        'localhost:50056',
        'localhost:50057'
    ]

# %%
import ast

string = "(\'A\', \'I\', 2)"
converted_list = list(ast.literal_eval(string))
print(converted_list)
# Out:
# ['A', 'I', 2]

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 list(1,2)
#
# TypeError: list expected at most 1 argument, got 2
